# %%
# %pip install pyodbc
# %pip install python-dotenv
#%pip install mitoinstaller

# %%
import pyodbc
from dotenv import dotenv_values
import pandas as pd
import warnings
import numpy as np
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer

warnings.filterwarnings('ignore')

# %%
environment_variables = dotenv_values('.env')

# geting values of the credentials in the '.env'file
database = environment_variables.get('DATABASE')
server = environment_variables.get('SERVER')
username = environment_variables.get('USERNAME')
password = environment_variables.get('PASSWORD')

connection_string = f"DRIVER={{SQL Server}};SERVER={server};DATABASE={database};UID={username};PWD={password}"

# %%
#Uing the connection method to connect to the server
connection  = pyodbc.connect(connection_string)

# %%
# sql query to get data
query = "select * from dbo.LP2_Telco_churn_first_3000"
data = pd.read_sql(query, connection)

# %%
data.head()
# Out:
#    customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0  7590-VHVEG  Female          False     True       False       1
# 1  5575-GNVDE    Male          False    False       False      34
# 2  3668-QPYBK    Male          False    False       False       2
# 3  7795-CFOCW    Male          False    False       False      45
# 4  9237-HQITU  Female          False    False       False       2
#
#    PhoneService MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0         False          None             DSL          False         True
# 1          True         False             DSL           True        False
# 2          True         False             DSL           True         True
# 3         False          None             DSL           True        False
# 4          True         False     Fiber optic          False        False
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0            False       False       False           False  Month-to-month
# 1             True       False       False           False        One year
# 2            False       False       False           False  Month-to-month
# 3             True        True       False           False        One year
# 4            False       False       False           False  Month-to-month
#
#    PaperlessBilling              PaymentMethod  MonthlyCharges  TotalCharges  \
# 0              True           Electronic check       29.850000     29.850000
# 1             False               Mailed check       56.950001   1889.500000
# 2              True               Mailed check       53.849998    108.150002
# 3             False  Bank transfer (automatic)       42.299999   1840.750000
# 4              True           Electronic check       70.699997    151.649994
#
#    Churn
# 0  False
# 1  False
# 2   True
# 3  False
# 4   True

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        3000 non-null   object
#  1   gender            3000 non-null   object
#  2   SeniorCitizen     3000 non-null   bool
#  3   Partner           3000 non-null   bool
#  4   Dependents        3000 non-null   bool
#  5   tenure            3000 non-null   int64
#  6   PhoneService      3000 non-null   bool
#  7   MultipleLines     2731 non-null   object
#  8   InternetService   3000 non-null   object
#  9   OnlineSecurity    2349 non-null   object
#  10  OnlineBackup      2349 non-null   object
#  11  DeviceProtection  2349 non-null   object
#  12  TechSupport       2349 non-null   object
#  13  StreamingTV       2349 non-null   object
#  14  StreamingMovies   2349 non-null   object
#  15  Contract          3000 non-null   object
#  16  PaperlessBilling  3000 non-null   bool
#  17  PaymentMethod     3000 non-null   object
#  18  MonthlyCharges    3000 non-null   float64
#  19  TotalCharges      2995 non-null   float64
#  20  Churn             2999 non-null   object
# dtypes: bool(5), float64(2), int64(1), object(13)
# memory usage: 389.8+ KB

# %%
# We need to see if we have any missing data
# Let's loop through the data and see if there is anything missing

for col in data.columns:
    pct_missing = np.mean(data[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# customerID - 0%
# gender - 0%
# SeniorCitizen - 0%
# Partner - 0%
# Dependents - 0%
# tenure - 0%
# PhoneService - 0%
# MultipleLines - 9%
# InternetService - 0%
# OnlineSecurity - 22%
# OnlineBackup - 22%
# DeviceProtection - 22%
# TechSupport - 22%
# StreamingTV - 22%
# StreamingMovies - 22%
# Contract - 0%
# PaperlessBilling - 0%
# PaymentMethod - 0%
# MonthlyCharges - 0%
# TotalCharges - 0%
# Churn - 0%

# %%
data["StreamingMovies"].value_counts()
# Out:
# True     1199
# False    1150
# Name: StreamingMovies, dtype: int64

# %%
data.fillna("None", inplace=True)
data.replace("None", np.nan, inplace = True)

# %%
data1 = pd.read_excel("Telco-churn-second-2000.xlsx")
data1.head()
# Out:
#    customerID gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7613-LLQFO   Male              0      No         No      12          Yes
# 1  4568-TTZRT   Male              0      No         No       9          Yes
# 2  9513-DXHDA   Male              0      No         No      27          Yes
# 3  2640-PMGFL   Male              0      No        Yes      27          Yes
# 4  3801-HMYNL   Male              0     Yes        Yes       1          Yes
#
#   MultipleLines InternetService       OnlineSecurity         OnlineBackup  \
# 0           Yes     Fiber optic                   No                   No
# 1            No              No  No internet service  No internet service
# 2            No             DSL                  Yes                   No
# 3           Yes     Fiber optic                   No                   No
# 4            No     Fiber optic                   No                   No
#
#       DeviceProtection          TechSupport          StreamingTV  \
# 0                   No                   No                  Yes
# 1  No internet service  No internet service  No internet service
# 2                  Yes                  Yes                  Yes
# 3                   No                  Yes                   No
# 4                   No                   No                  Yes
#
#        StreamingMovies        Contract PaperlessBilling     PaymentMethod  \
# 0                   No  Month-to-month              Yes  Electronic check
# 1  No internet service  Month-to-month               No      Mailed check
# 2                  Yes        One year               No  Electronic check
# 3                   No  Month-to-month              Yes  Electronic check
# 4                  Yes  Month-to-month               No      Mailed check
#
#    MonthlyCharges TotalCharges
# 0           84.45      1059.55
# 1           20.40        181.8
# 2           81.70      2212.55
# 3           79.50      2180.55
# 4           89.15        89.15

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        2000 non-null   object
#  1   gender            2000 non-null   object
#  2   SeniorCitizen     2000 non-null   int64
#  3   Partner           2000 non-null   object
#  4   Dependents        2000 non-null   object
#  5   tenure            2000 non-null   int64
#  6   PhoneService      2000 non-null   object
#  7   MultipleLines     2000 non-null   object
#  8   InternetService   2000 non-null   object
#  9   OnlineSecurity    2000 non-null   object
#  10  OnlineBackup      2000 non-null   object
#  11  DeviceProtection  2000 non-null   object
#  12  TechSupport       2000 non-null   object
#  13  StreamingTV       2000 non-null   object
#  14  StreamingMovies   2000 non-null   object
#  15  Contract          2000 non-null   object
#  16  PaperlessBilling  2000 non-null   object
#  17  PaymentMethod     2000 non-null   object
#  18  MonthlyCharges    2000 non-null   float64
#  19  TotalCharges      2000 non-null   object
# dtypes: float64(1), int64(2), object(17)
# memory usage: 312.6+ KB

# %%
data2 = pd.read_csv("LP2_Telco-churn-last-2000.csv")
data2.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  5600-PDUJF    Male              0      No         No       6          Yes
# 1  8292-TYSPY    Male              0      No         No      19          Yes
# 2  0567-XRHCU  Female              0     Yes        Yes      69           No
# 3  1867-BDVFH    Male              0     Yes        Yes      11          Yes
# 4  2067-QYTCF  Female              0     Yes         No      64          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0                No             DSL             No           No
# 1                No             DSL             No           No
# 2  No phone service             DSL            Yes           No
# 3               Yes     Fiber optic             No           No
# 4               Yes     Fiber optic             No          Yes
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No         Yes          No              No  Month-to-month
# 1              Yes         Yes          No              No  Month-to-month
# 2              Yes          No          No             Yes        Two year
# 3               No          No          No              No  Month-to-month
# 4              Yes         Yes         Yes             Yes  Month-to-month
#
#   PaperlessBilling            PaymentMethod  MonthlyCharges TotalCharges Churn
# 0              Yes  Credit card (automatic)           49.50        312.7    No
# 1              Yes  Credit card (automatic)           55.00       1046.5   Yes
# 2              Yes  Credit card (automatic)           43.95       2960.1    No
# 3              Yes         Electronic check           74.35        834.2   Yes
# 4              Yes         Electronic check          111.15       6953.4    No

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2043 entries, 0 to 2042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        2043 non-null   object
#  1   gender            2043 non-null   object
#  2   SeniorCitizen     2043 non-null   int64
#  3   Partner           2043 non-null   object
#  4   Dependents        2043 non-null   object
#  5   tenure            2043 non-null   int64
#  6   PhoneService      2043 non-null   object
#  7   MultipleLines     2043 non-null   object
#  8   InternetService   2043 non-null   object
#  9   OnlineSecurity    2043 non-null   object
#  10  OnlineBackup      2043 non-null   object
#  11  DeviceProtection  2043 non-null   object
#  12  TechSupport       2043 non-null   object
#  13  StreamingTV       2043 non-null   object
#  14  StreamingMovies   2043 non-null   object
#  15  Contract          2043 non-null   object
#  16  PaperlessBilling  2043 non-null   object
#  17  PaymentMethod     2043 non-null   object
#  18  MonthlyCharges    2043 non-null   float64
#  19  TotalCharges      2043 non-null   object
#  20  Churn             2043 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 335.3+ KB

# %%
d = pd.DataFrame({"col_name":data.columns.values.tolist()})

d1 = pd.DataFrame({"col_name":data1.columns.values.tolist()})

d2 = pd.DataFrame({"col_name":data2.columns.values.tolist()})

# %%
d.isin(d2)
# Out:
#     col_name
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
# 5       True
# 6       True
# 7       True
# 8       True
# 9       True
# 10      True
# 11      True
# 12      True
# 13      True
# 14      True
# 15      True
# 16      True
# 17      True
# 18      True
# 19      True
# 20      True

# %%
d["col_name"][20], d2["col_name"][20]
# Out:
# ('Churn', 'Churn')

# %%
data[data.isna().any(axis=1)]
# Out:
#               customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0             7590-VHVEG  Female          False     True       False       1
# 3             7795-CFOCW    Male          False    False       False      45
# 7             6713-OKOMC  Female          False    False       False      10
# 11            7469-LKBCI    Male          False    False       False      16
# 16            8191-XWSZG  Female          False    False       False      52
# 20            8779-QRDMV    Male           True    False       False       1
# 21            1680-VDCWW    Male          False     True       False      12
# 22            1066-JKSGK    Male          False    False       False       1
# 27            8665-UTDHZ    Male          False     True        True       1
# 33            7310-EGVHZ    Male          False    False       False       1
# 42            9867-JCZSP  Female          False     True        True      17
# 58            3957-SQXML  Female          False     True        True      34
# 62            0526-SXDJP    Male          False     True       False      72
# 68            3170-NMYVV  Female          False     True        True      50
# 71            0731-EBJQB  Female          False     True        True      52
# 73            8028-PNXHQ    Male          False     True        True      62
# 79            3887-PBQAO  Female          False     True        True      45
# 81            8108-UXRQN  Female          False     True        True      11
# 84            0318-ZOPWS  Female          False     True       False      49
# 87            1862-QRWPE  Female          False     True        True      48
# 88            2796-NNUFI  Female          False     True        True      46
# 89            3016-KSVCP    Male          False     True       False      29
# 97            0278-YXOOG    Male          False    False       False       5
# 98            3212-KXOCR    Male          False    False       False      52
# 100           6380-ARCEH    Male          False    False       False       1
# 101           3679-XASPY  Female          False     True        True       1
# 103           5386-THSLQ  Female           True     True       False      66
# 105           6180-YBIQI    Male          False    False       False       5
# 107           9750-BOOHV  Female          False    False       False      32
# 109           2848-YXSMW    Male          False     True        True      72
# 114           5256-SKJGO  Female          False     True        True      64
# 116           9560-BBZXK  Female          False    False       False      36
# 118           8402-OOOHJ  Female          False    False       False      41
# 121           2928-HLDBA  Female          False    False       False       6
# 124           7219-TLZHO  Female          False     True        True       4
# 127           6734-PSBAW    Male          False     True       False      72
# 128           3930-ZGWVE    Male          False    False       False       1
# 129           2639-UGMAZ    Male           True    False       False      71
# 131           6207-WIOLX  Female          False     True        True      25
# 133           3091-FYHKI    Male          False    False       False       1
# 135           7799-LGRDP  Female          False    False       False      43
# 137           3774-VBNXY  Female          False     True        True      64
# 138           6217-KDYWC    Male          False    False        True      57
# 144           1131-QQZEB    Male           True     True       False      71
# 146           6837-BJYDQ    Male          False    False       False       3
# 154           3077-RSNTJ  Female          False     True        True       6
# 157           2749-CTKAJ    Male          False     True        True      22
# 159           7554-NEWDD    Male          False    False       False      10
# 164           2907-ILJBN  Female          False     True        True      11
# 165           6345-FZOQH    Male          False     True       False      69
# 168           3445-HXXGF    Male           True     True       False      58
# 169           1159-WFSGR  Female          False     True        True      16
# 174           5918-VUKWP  Female          False    False       False      32
# 175           1744-JHKYS  Female          False     True       False      34
# 179           3712-PKXZA    Male          False     True       False      61
# 180           6317-YPKDH  Female          False    False       False       1
# 185           1024-GUALD  Female          False     True       False       1
# 187           8167-GJLRN    Male          False    False       False       3
# 188           0956-SYCWG  Female          False    False       False      13
# 192           2984-RGEYA  Female          False     True        True      69
# 194           2146-EGVDT    Male          False     True        True      59
# 196           9178-JHUVJ    Male          False     True        True      24
# 199           3645-DEYGF    Male          False    False        True       1
# 206           6348-SNFUS    Male          False     True        True      72
# 211           4195-NZGTA  Female          False    False       False       1
# 212           7157-SMCFK    Male          False    False        True      61
# 213           4709-LKHYG  Female          False     True        True      29
# 215           0699-NDKJM  Female          False     True       False      57
# 216           9286-BHDQG    Male          False     True        True      72
# 217           0230-WEQUW    Male          False     True       False      66
# 221           4443-EMBNA  Female          False     True       False      71
# 222           6469-MRVET    Male          False     True        True       1
# 224           5961-VUSRV  Female          False    False       False      12
# 225           6778-JFCMK    Male          False    False       False      24
# 233           7083-MIOPC  Female          False    False       False      72
# 234           1984-GPTEH  Female          False    False       False      29
# 236           0621-JFHOL  Female          False    False       False      10
# 239           9227-UAQFT    Male          False    False       False      16
# 252           9514-JDSKI    Male           True     True       False       1
# 254           3675-YDUPJ    Male          False    False       False      10
# 255           4111-BNXIF  Female          False     True        True      67
# 259           5046-NUHWD  Female           True     True       False      29
# 260           7273-TEFQD    Male           True    False       False       3
# 263           7605-BDWDC  Female          False    False       False      31
# 266           6292-TOSSS    Male          False    False       False      50
# 268           6323-AYBRX    Male          False    False       False      59
# 269           7014-ZZXAW  Female          False     True       False      71
# 272           6366-ZGQGL    Male          False    False       False       1
# 278           8645-KWHJO    Male          False    False       False      14
# 282           2080-SRCDE  Female          False    False        True       1
# 294           1563-IWQEX  Female          False    False       False      12
# 295           8203-XJZRC    Male          False    False       False       1
# 303           8181-YHCMF  Female          False     True        True      68
# 305           1248-DYXUB    Male          False     True        True      52
# 310           1098-TDVUQ  Female          False    False       False       1
# 316           3973-SKMLN    Male          False    False       False      71
# 321           9880-TDQAC  Female          False     True        True      72
# 324           8626-PTQGE    Male          False    False       False      69
# 328           5697-GOMBF  Female           True     True        True      28
# 330           9385-EHGDO  Female          False     True        True      35
# 331           9498-FIMXL  Female          False    False       False       8
# 343           9639-BUJXT    Male          False    False       False      63
# 344           5924-SNGKP  Female          False    False        True      41
# 347           8966-SNIZF  Female          False     True       False      70
# 348           6243-OZGFH  Female          False    False       False      23
# 354           0623-IIHUG  Female           True    False       False      21
# 358           9057-MSWCO    Male           True     True       False      27
# 360           9294-TDIPC    Male          False    False        True       5
# 363           5176-LMJXE  Female          False    False       False      47
# 367           7302-ZHMHP  Female          False    False       False       1
# 370           6563-VRERX    Male          False     True        True      33
# 372           6122-EFVKN    Male          False    False        True      24
# 376           6158-HDPXZ    Male          False    False       False       1
# 382           8204-YJCLA    Male           True     True        True      72
# 385           4895-TMWIR    Male           True     True       False      11
# 387           1708-PBBOA  Female          False    False       False      42
# 393           9967-ATRFS  Female          False    False       False      19
# 398           2519-ERQOJ    Male           True    False       False      33
# 399           5876-QMYLD  Female          False     True        True      23
# 400           2277-AXSDC  Female          False    False       False      32
# 401           9442-JTWDL  Female          False    False       False      11
# 404           5495-GPSRW    Male          False    False       False      20
# 405           7606-BPHHN    Male          False    False       False      72
# 408           4800-VHZKI  Female          False    False       False       1
# 409           7989-CHGTL    Male          False    False       False       1
# 411           4163-NCJAK  Female          False     True       False      46
# 417           5249-QYHEX  Female          False     True        True      40
# 420           2233-FAGXV  Female          False     True        True       5
# 423           3935-TBRZZ    Male          False     True        True      44
# 424           8111-BKVDS  Female          False    False       False      10
# 430           9063-ZGTUY  Female          False     True        True      61
# 431           7781-HVGMK  Female          False     True        True      72
# 434           6048-NJXHX    Male          False     True       False      41
# 435           2320-SLKMB  Female          False    False       False      26
# 436           4980-URKXC    Male          False     True       False      36
# 447           0732-OCQOC  Female          False     True        True      52
# 450           8592-PLTMQ  Female          False    False       False      64
# 452           8847-GEOOQ    Male          False     True       False      60
# 454           4785-FCIFB  Female          False     True       False      61
# 458           4237-CLSMM    Male          False     True       False       2
# 460           4719-UMSIY    Male          False    False        True       6
# 465           2996-XAUVF    Male          False    False       False      70
# 468           8896-RAZCR  Female          False    False        True      44
# 470           4933-IKULF  Female           True    False       False      17
# 480           0486-LGCCH    Male          False     True        True      11
# 481           0447-BEMNG  Female          False     True       False      48
# 488           4472-LVYGI  Female          False     True        True       0
# 494           6579-JPICP    Male          False    False       False       1
# 495           8205-OTCHB    Male          False    False       False      22
# 497           0505-SPOOW  Female          False     True       False      70
# 498           6235-VDHOM  Female           True    False       False       5
# 509           1135-LMECX  Female          False    False       False       1
# 519           7531-GQHME    Male          False    False       False      12
# 528           7601-GNDYK    Male          False     True        True      35
# 530           8067-NIOYM  Female          False     True        True      24
# 531           1403-GYAFU    Male          False     True        True      70
# 542           2866-IKBTM  Female          False    False       False       1
# 544           2817-NTQDO    Male          False    False       False      13
# 549           8138-EALND    Male          False    False       False      15
# 552           2075-PUEPR    Male          False     True        True      55
# 553           1982-FEBTD  Female          False     True        True      23
# 556           2654-VBVPB  Female          False    False       False       1
# 561           7343-EOBEU    Male          False     True       False       3
# 569           0308-IVGOK  Female          False    False       False      11
# 570           7293-LSCDV  Female          False     True        True      60
# 579           2640-LYMOV    Male          False    False       False       2
# 580           1218-VKFPE  Female          False     True        True      12
# 583           1423-BMPBQ  Female          False     True        True       1
# 584           2393-DIVAI  Female          False    False       False       3
# 587           8752-IMQOS    Male          False     True        True       5
# 591           5512-IDZEI    Male          False     True        True      46
# 596           8208-EUMTE    Male          False    False       False      16
# 599           0374-FIUCA    Male          False     True       False      65
# 601           5173-ZXXXL    Male          False    False       False       2
# 610           6543-CPZMK    Male          False     True        True       9
# 612           2804-ETQDK    Male          False    False        True      66
# 616           6464-KEXXH    Male          False    False       False       8
# 620           4881-JVQOD    Male           True     True        True      10
# 623           5148-HKFIR  Female          False    False       False      20
# 624           1009-IRMNA  Female          False    False       False       7
# 633           7665-VIGUD    Male          False    False       False      10
# 634           9411-TPQQV  Female          False    False       False      40
# 640           9574-BOSMD    Male          False     True        True      68
# 644           8404-VLQFB  Female          False     True        True      15
# 652           5845-BZZIB    Male          False     True        True      35
# 653           1140-UKVZG  Female          False    False       False      17
# 654           4160-AMJTL  Female           True    False       False       8
# 658           4464-JCOLN    Male          False     True        True       2
# 659           2085-JVGAD    Male          False     True       False      37
# 660           5650-VDUDS  Female          False    False       False       4
# 662           3030-ZKIWL    Male          False    False       False       1
# 664           8755-OGKNA  Female          False     True        True      57
# 667           5533-RJFTJ    Male          False    False       False      49
# 669           0214-JHPFW  Female          False     True       False      70
# 670           5642-MHDQT  Female          False     True        True      53
# 671           3088-FVYWK    Male          False     True        True      53
# 673           9092-GDZKO    Male          False    False       False      22
# 674           0823-HSCDJ    Male           True    False       False      52
# 676           2324-AALNO  Female          False    False       False      48
# 677           0822-GAVAP  Female          False    False       False       2
# 686           5313-FPXWG    Male          False    False       False      51
# 688           0946-FKYTX    Male          False    False       False      52
# 690           8262-COGGB    Male          False    False       False       1
# 692           9620-QJREV    Male          False    False        True      47
# 694           2682-KEVRP  Female           True    False       False      22
# 695           2480-JZOSN  Female          False     True       False       1
# 703           6942-LBFDP  Female          False    False       False       2
# 710           1029-QFBEN    Male          False    False       False       1
# 712           9661-JALZV  Female          False    False       False      58
# 714           4312-KFRXN    Male          False     True       False      72
# 716           0114-IGABW  Female          False     True       False      71
# 718           1853-ARAAQ  Female          False    False       False      26
# 720           4697-LUPSU    Male          False     True        True       2
# 721           8434-VGEQQ    Male          False     True        True      61
# 725           6549-YMFAW    Male           True     True       False       9
# 726           4950-HKQTE  Female          False    False       False      22
# 731           6621-YOBKI    Male          False    False       False       5
# 735           7595-EHCDL    Male          False     True        True      32
# 743           4018-PPNDW  Female          False     True        True      61
# 748           6425-JWTDV    Male          False     True       False      48
# 753           3115-CZMZD    Male          False    False        True       0
# 756           5730-DBDSI    Male          False    False       False      66
# 757           0030-FNXPP  Female          False    False       False       3
# 760           4013-GUXND    Male          False    False       False       1
# 764           7969-FFOWG    Male          False     True        True      65
# 765           4718-DHSMV  Female          False    False       False      11
# 767           7817-OMJNA    Male          False    False       False      14
# 770           7706-DZNKK    Male          False    False       False      11
# 772           3900-AQPHZ  Female          False    False       False       1
# 776           9505-SQFSW  Female          False     True        True       3
# 784           5125-CNDSP    Male          False    False        True      63
# 790           7131-ZQZNK  Female          False     True        True      60
# 792           5726-CVNYA  Female          False     True        True       8
# 794           4257-GAESD  Female          False    False       False       6
# 797           6286-ZHAOK  Female          False     True        True      20
# 798           3807-XHCJH  Female          False     True        True       1
# 802           8859-AXJZP    Male          False     True        True      39
# 812           8098-TDCBU  Female          False     True       False      42
# 813           3551-GAEGL    Male          False     True        True      34
# 814           4785-NKHCX    Male           True    False       False       5
# 824           4335-BSMJS  Female          False    False       False      62
# 827           9146-JRIOX  Female          False     True        True      14
# 829           5337-IIWKZ    Male          False     True        True      34
# 831           9650-VBUOG    Male          False     True        True      38
# 839           4625-LAMOB    Male          False    False       False      44
# 842           1038-ZAGBI  Female          False     True        True      12
# 843           6549-NNDYT  Female          False    False       False      13
# 845           0422-OHQHQ  Female          False     True        True      15
# 847           2316-ESMLS  Female          False     True        True      12
# 852           8713-IGZSO    Male          False    False       False       2
# 854           7695-PKLCZ  Female          False    False       False      68
# 859           5275-PMFUT    Male          False     True        True      72
# 860           4795-UXVCJ    Male          False    False       False      26
# 866           0979-MOZQI    Male          False     True       False      62
# 867           2732-ISEZX  Female          False    False       False       5
# 869           0323-XWWTN    Male          False    False        True       3
# 872           1764-VUUMT    Male          False    False        True      66
# 873           5073-WXOYN  Female          False    False       False      60
# 875           3050-GBUSH  Female          False    False       False       3
# 877           7876-AEHIG  Female          False    False        True      51
# 881           3523-BRGUW    Male           True    False       False      26
# 884           5170-PTRKA  Female          False     True        True      49
# 885           4661-NJEUX    Male          False    False       False       1
# 893           9227-LUNBG  Female          False    False       False       1
# 900           1051-GEJLJ  Female          False    False       False       2
# 908           4694-PHWFW  Female          False    False        True       8
# 913           5993-BQHEA    Male          False    False       False      12
# 914           6024-RUGGH    Male          False     True        True      72
# 917           4079-WWQQQ    Male          False    False       False      72
# 920           7471-WNSUF    Male          False     True       False      60
# 921           8942-DBMHZ    Male          False    False       False      12
# 932           5787-KXGIY    Male          False     True       False      72
# 934           4198-VFOEA  Female          False    False       False      12
# 936           5709-LVOEQ  Female          False     True        True       0
# 939           0347-UBKUZ  Female          False    False       False      15
# 940           0835-DUUIQ  Female          False    False        True      24
# 941           0811-GSDTP  Female          False    False        True      13
# 943           6115-ZTBFQ  Female          False     True       False      72
# 946           6231-WFGFH    Male          False     True        True       4
# 949           6169-PPETC    Male          False     True        True      35
# 956           3261-CQXOL  Female          False     True        True      71
# 960           2826-DXLQO    Male           True     True       False       7
# 961           4378-BZYFP    Male          False    False       False      17
# 966           4541-RMRLG    Male          False    False       False       7
# 967           7764-BDPEE    Male          False    False        True       3
# 973           8919-FYFQZ    Male           True     True       False      44
# 980           3318-ISQFQ  Female          False    False       False      20
# 981           1106-HRLKZ    Male          False     True        True      40
# 984           8165-ZJRNM  Female          False     True        True      72
# 987           3717-OFRTN    Male          False    False       False       1
# 988           9046-JBFWA    Male          False    False        True      27
# 989           3280-NMUVX    Male          False     True        True      34
# 991           8361-LBRDI  Female          False    False       False      58
# 992           4883-KCPZJ  Female          False     True        True      22
# 993           9108-EQPNQ  Female          False     True        True      10
# 994           7277-KAMWT    Male          False    False       False      13
# 998           2545-LXYVJ    Male          False     True       False      72
# 1003          8917-FAEMR  Female          False    False       False      37
# 1004          7047-YXDMZ    Male          False    False       False      21
# 1009          6419-ZTTLE    Male           True     True       False      23
# 1011          6614-YOLAC  Female          False     True        True      71
# 1017          9361-YNQWJ  Female          False    False       False      64
# 1018          3748-FVMZZ    Male          False    False       False       4
# 1019          9391-TTOYH  Female          False    False       False      23
# 1033          2632-TACXW  Female          False     True       False      62
# 1035          1767-CJKBA    Male          False    False       False      66
# 1037          4581-LNWUM  Female          False    False       False      13
# 1041          1915-OAKWD  Female          False    False        True      16
# 1048          2829-HYVZP    Male          False    False       False      29
# 1049          8329-IBCTI  Female          False    False       False       1
# 1050          1271-SJBGZ    Male           True    False       False      12
# 1051          3845-JHAMY  Female          False     True        True      16
# 1053          5669-SRAIP  Female          False    False       False       5
# 1055          3486-NPGST  Female          False    False       False      36
# 1060          6100-FJZDG    Male          False     True        True      26
# 1066          9646-NMHXE    Male          False     True       False      47
# 1072          7771-ZONAT    Male          False    False       False      22
# 1074          2111-DWYHN    Male          False    False       False       1
# 1076          4121-AGSIN  Female          False     True        True      58
# 1080          0301-KOBTQ    Male          False    False       False      32
# 1082          4367-NUYAO    Male          False     True        True       0
# 1084          9170-ARBTB  Female          False     True        True      52
# 1100          9578-FOMUK    Male          False    False        True      15
# 1101          4712-UYOOI  Female          False     True        True      20
# 1104          8717-VCTXJ    Male          False    False       False      42
# 1107          0971-QIFJK  Female          False     True       False      69
# 1108          9397-TZSHA  Female          False    False       False      69
# 1110          0343-QLUZP    Male          False    False       False      60
# 1116          8461-EFQYM  Female          False    False       False      38
# 1119          1459-QNFQT    Male          False     True        True      70
# 1122          4081-DYXAV  Female          False    False       False      19
# 1128          0098-BOWSO    Male          False    False       False      27
# 1130          5859-HZYLF    Male          False     True        True      26
# 1133          3156-QLHBO    Male          False    False        True       2
# 1136          6621-NRZAK  Female          False     True        True      63
# 1137          0831-JNISG    Male          False     True        True      71
# 1139          3082-WQRVY    Male           True     True       False      14
# 1141          1641-BYBTK    Male          False    False        True       6
# 1144          0841-NULXI    Male          False    False       False       1
# 1146          1430-SFQSA    Male          False    False       False      29
# 1150          8807-ARQET  Female          False    False       False      41
# 1151          8992-CEUEN  Female          False    False       False       1
# 1154          8292-ITGYJ  Female          False     True        True      45
# 1156          0621-CXBKL  Female          False    False       False      53
# 1161          5868-CZJDR    Male          False    False        True       1
# 1165          6479-OAUSD    Male          False    False       False      25
# 1168          5562-BETPV    Male          False     True        True       1
# 1169          1282-IHQAC    Male           True    False       False      70
# 1173          0107-WESLM    Male          False    False       False       1
# 1182          3164-YAXFY    Male          False    False       False      57
# 1197          8944-AILEF    Male          False     True       False      15
# 1198          5542-NKVRU  Female          False    False       False      42
# 1203          9087-EYCPR  Female          False    False       False      60
# 1204          6791-YBNAK    Male          False     True        True      18
# 1213          6980-IMXXE  Female          False     True        True      69
# 1216          0040-HALCW    Male          False     True        True      54
# 1217          0784-GTUUK    Male          False     True       False      62
# 1221          3055-MJDSB    Male          False    False       False       9
# 1225          6581-NQCBA  Female          False     True       False      16
# 1226          7115-IRDHS  Female          False     True       False      72
# 1233          1299-AURJA  Female          False     True        True      70
# 1237          2788-CJQAQ    Male          False    False       False      13
# 1240          2120-SMPEX    Male          False    False       False      25
# 1242          0668-OGMHD  Female          False     True       False      21
# 1244          2223-KAGMX  Female          False    False       False      15
# 1252          7617-EYGLW    Male          False    False       False       1
# 1255          4030-VPZBD  Female          False    False       False       2
# 1257          0723-VSOBE  Female           True    False       False      45
# 1258          5529-GIBVH  Female          False    False       False      47
# 1270          8780-IHCRN    Male          False     True        True      63
# 1271          4598-ZADCK  Female          False    False       False      53
# 1272          1257-SXUXQ    Male          False     True        True       5
# 1277          4821-WQOYN  Female          False     True        True      72
# 1278          4730-AWNAU    Male          False     True        True      36
# 1279          3452-FLHYD    Male          False     True       False      25
# 1281          9531-NSBMR  Female          False    False       False      36
# 1284          8711-LOBKY    Male          False     True        True      59
# 1288          2616-FLVQC    Male          False    False       False      64
# 1298          5989-OMNJE  Female          False     True        True      24
# 1303          0042-RLHYP  Female          False     True        True      69
# 1311          3941-XTSKM    Male          False     True        True      42
# 1315          5158-RIVOP  Female          False     True        True      11
# 1316          9788-YTFGE    Male          False    False       False       7
# 1317          9277-JOOMO  Female          False    False       False       3
# 1319          1725-MIMXW    Male          False    False        True       1
# 1322          0114-RSRRW  Female          False     True       False      10
# 1323          4565-NLZBV  Female          False     True       False      71
# 1324          0031-PVLZI  Female          False     True        True       4
# 1326          6682-VCIXC  Female          False     True        True      43
# 1329          3910-MRQOY  Female          False     True       False      72
# 1331          7537-RBWEA  Female          False    False       False       1
# 1332          4656-CAURT    Male          False    False       False      69
# 1333          0121-SNYRK    Male          False    False       False      50
# 1334          1768-ZAIFU  Female           True    False       False       1
# 1337          6265-FRMTQ    Male          False    False       False      31
# 1338          1934-SJVJK    Male          False    False       False       1
# 1340          1371-DWPAZ  Female          False     True        True       0
# 1342          2017-CCBLH  Female          False    False       False       8
# 1344          0536-BGFMZ  Female          False     True       False      28
# 1347          5469-NUJUR    Male          False    False       False      19
# 1349          2625-TRCZQ  Female          False     True       False      51
# 1351          7266-GSSJX    Male          False     True        True      11
# 1352          7722-VJRQD    Male          False     True        True      72
# 1353          7073-QETQY    Male          False     True        True      66
# 1355          5624-RYAMH  Female          False    False       False       9
# 1365          7721-JXEAW    Male          False     True       False      59
# 1370          7596-IIWYC  Female          False    False       False      27
# 1373          4291-HPAXL    Male          False    False        True       1
# 1375          1839-FBNFR  Female          False     True        True      39
# 1379          0562-KBDVM  Female          False    False       False      70
# 1382          4538-WNTMJ  Female          False     True        True      46
# 1387          7684-XSZIY    Male          False     True        True      72
# 1392          1934-MKPXS    Male          False     True        True      33
# 1393          2592-YKDIF  Female          False    False       False       1
# 1399          3131-NWVFJ  Female          False     True        True      14
# 1400          7521-YXVZY    Male          False    False        True       3
# 1402          6240-EURKS  Female          False    False        True      18
# 1404          1970-KKFWL  Female          False    False       False      35
# 1406          9337-SRRNI    Male          False    False        True      66
# 1407          0895-UADGO    Male          False    False        True       8
# 1416          4859-ZSRDZ  Female          False     True        True      58
# 1419          3498-LZGQZ    Male          False     True        True      63
# 1424          7560-QRBXH  Female          False    False        True      48
# 1429          4652-ODEVH    Male          False     True        True      45
# 1430          6510-UPNKS  Female          False    False       False      23
# 1432          9046-DQMTP    Male          False    False       False      35
# 1440          7677-SJJJK    Male          False     True        True       8
# 1448          2958-NHPPS    Male          False    False       False      23
# 1449          6806-YDEUL  Female           True    False       False       6
# 1450          1735-XMJVH    Male          False     True        True       8
# 1452          0222-CNVPT    Male           True    False       False      52
# 1454          8681-ICONS    Male          False     True        True      29
# 1458          7893-IXHRQ    Male          False    False       False       1
# 1462          9824-QCJPK    Male          False     True       False      36
# 1470          6979-TNDEU  Female          False    False       False       8
# 1476          5067-DGXLL    Male          False    False       False       2
# 1479          6281-FKEWS  Female          False    False       False      44
# 1480          8898-KASCD    Male          False    False       False      39
# 1481          9242-TKFSV    Male          False     True        True      72
# 1491          8605-ITULD  Female          False    False       False       1
# 1494          2667-WYLWJ  Female          False     True        True       8
# 1496          3195-TQDZX    Male          False    False       False       3
# 1500          7041-TXQJH  Female          False    False       False      37
# 1501          5014-GSOUQ    Male          False    False       False      13
# 1506          8819-WFGGJ    Male          False     True       False      68
# 1507          7427-AUFPY    Male          False    False       False      54
# 1511          9972-EWRJS  Female          False     True        True      67
# 1513          0661-XEYAN  Female           True    False       False       1
# 1514          5799-JRCZO  Female          False    False        True      63
# 1518          1925-GMVBW  Female          False    False       False       5
# 1519          7881-EVUAD  Female          False    False       False       2
# 1520          6184-DYUOB  Female          False     True       False       3
# 1525          3012-VFFMN  Female          False     True        True       7
# 1527          0640-YJTPY    Male          False     True        True      72
# 1529          9764-REAFF  Female          False     True       False      59
# 1531          7107-UBYKY  Female          False     True        True      35
# 1532          4881-GQJTW    Male          False    False       False      14
# 1534          7876-DNYAP  Female          False     True        True      69
# 1541          2429-AYKKO    Male          False    False       False      72
# 1542          9798-OPFEM  Female          False    False       False      46
# 1546          7114-AEOZE  Female          False    False       False      60
# 1551          6518-KZXCB    Male          False    False       False      22
# 1554          9313-QOLTZ    Male          False    False       False      26
# 1559          9818-XQCUV  Female          False    False       False       2
# 1560          7338-ERIVA    Male          False    False        True      39
# 1562          8259-NFJTV  Female          False     True        True       7
# 1570          3070-FNFZQ  Female          False     True        True      23
# 1571          2812-SFXMJ    Male          False    False        True       1
# 1574          5312-TSZVC  Female          False    False        True      15
# 1581          2782-JEEBU    Male          False    False       False      21
# 1584          9906-NHHVC  Female           True    False       False      65
# 1587          5939-SXWHM    Male          False     True        True      48
# 1590          7643-RCHXS  Female          False     True        True      63
# 1591          8246-SHFGA    Male          False    False       False      17
# 1593          0620-XEFWH    Male          False     True        True       4
# 1594          6485-QXWWE  Female          False    False        True      62
# 1598          7552-KEYGT    Male          False     True       False      27
# 1605          7941-RCJOW    Male          False    False       False      65
# 1608          2387-KDZQY    Male          False    False       False      17
# 1613          3374-PZLXD    Male          False    False       False      34
# 1614          3813-DHBBB    Male          False     True       False      67
# 1615          2812-REYAT  Female          False     True       False      49
# 1616          6518-PPLMZ    Male          False     True        True      53
# 1620          6022-KOUQO  Female          False     True        True       2
# 1634          9995-HOTOH    Male          False     True        True      63
# 1636          1371-OJCEK  Female          False    False       False      48
# 1637          4999-IEZLT    Male          False    False       False      66
# 1640          2351-RRBUE  Female          False     True        True       7
# 1642          1498-DQNRX  Female          False     True       False      29
# 1652          3307-TLCUD    Male          False     True       False      17
# 1653          6625-FLENO    Male          False     True       False      58
# 1654          2967-MXRAV    Male          False     True        True       1
# 1657          4163-KIUHY    Male          False    False       False      35
# 1660          1171-TYKUR    Male          False     True       False      47
# 1666          8388-DMKAE  Female          False    False       False       8
# 1667          4403-BWPAY    Male          False    False       False      14
# 1674          2808-CHTDM  Female          False     True        True      23
# 1677          3283-WCWXT    Male          False     True        True       6
# 1680          5451-MHQOF    Male          False     True        True      56
# 1681          4836-WNFNO  Female          False     True       False      72
# 1683          0354-VXMJC    Male          False     True        True      23
# 1687          8332-OSJDW    Male          False     True        True      12
# 1688          4735-BJKOU  Female          False    False       False      40
# 1689          0274-JKUJR    Male          False     True        True       7
# 1691          8917-SZTTJ    Male          False     True        True      60
# 1692          1696-MZVAU    Male          False     True        True      39
# 1694          0375-HVGXO  Female          False    False       False       1
# 1699          6223-DHJGV  Female          False    False       False      42
# 1700          6961-MJKBO    Male          False    False       False      47
# 1703          8158-WPEZG    Male          False    False       False      11
# 1711          9964-WBQDJ  Female          False     True       False      71
# 1715          0386-CWRGM  Female          False     True        True      46
# 1717          0404-AHASP    Male          False     True       False      72
# 1718          7279-NMVJC  Female          False    False       False      17
# 1722          9060-HJJRW  Female          False    False       False      51
# 1723          2587-YNLES  Female          False     True        True       6
# 1733          1015-OWJKI    Male          False    False       False       1
# 1734          7511-YMXVQ    Male          False    False       False       9
# 1736          7551-JOHTI  Female          False    False       False       1
# 1740          1222-KJNZD    Male          False     True        True      40
# 1743          3768-VHXQO    Male          False     True       False      67
# 1745          2418-TPEUN  Female          False     True        True      56
# 1748          8540-ZQGEA  Female          False     True       False      54
# 1758          5848-FHRFC  Female          False    False       False      68
# 1759          2243-FNMMI    Male          False    False       False      20
# 1761          5356-KZCKT    Male          False    False       False      58
# 1766          8763-KIAFH  Female          False     True        True      27
# 1773          2007-QVGAW  Female          False     True        True      68
# 1776          5605-XNWEN    Male           True     True       False      72
# 1778          6181-AXXYF    Male          False     True        True      72
# 1780          0516-VRYBW  Female          False    False        True      18
# 1784          5687-DKDTV  Female          False    False       False       4
# 1788          7416-CKTEP  Female          False     True       False      57
# 1789          2586-CWXVV    Male          False     True       False      54
# 1793          4193-IBKSW    Male          False     True        True      72
# 1797          0839-QNXME  Female          False    False       False      30
# 1798          3506-OVLKD    Male          False    False       False      35
# 1802          7492-TAFJD    Male          False     True        True       7
# 1803          2773-MADBQ  Female          False    False       False      36
# 1804          6016-LVTJQ  Female          False     True        True      34
# 1806          8966-KZXXA    Male          False     True        True      36
# 1814          5442-PPTJY    Male          False     True        True      12
# 1815          1927-QEWMY  Female          False     True       False      72
# 1816          1663-MHLHE    Male          False    False       False       1
# 1819          6701-DHKWQ  Female          False     True        True      61
# 1824          0794-YVSGE    Male          False     True        True      72
# 1827          2959-EEXWB  Female          False     True        True      45
# 1828          1839-UMACK    Male          False    False       False      42
# 1830          7321-KKSDU    Male          False    False        True      32
# 1832          3132-TVFDZ    Male           True     True       False      57
# 1837          1349-WXNGG    Male          False    False       False       1
# 1839          9350-ZXYJC  Female          False    False       False       4
# 1841          8958-JPTRR  Female          False     True       False      56
# 1843          3173-WSSUE  Female          False     True        True      71
# 1845          4115-UMJFQ    Male          False    False       False      69
# 1846          7369-TRPFD    Male          False    False       False      19
# 1847          1098-KFQEC  Female          False     True        True      55
# 1848          7190-XHTWJ  Female          False    False       False      38
# 1851          2485-ITVKB  Female          False     True       False       2
# 1854          6702-OHFWR    Male           True    False       False       1
# 1855          5296-BFCYD    Male          False     True        True      46
# 1860          3279-DYZQM    Male          False     True        True      71
# 1862          0523-VNGTF  Female           True    False       False      52
# 1863          9575-IWCAZ    Male          False     True       False       6
# 1869          7010-BRBUU    Male          False     True        True      72
# 1872          9938-PRCVK  Female          False     True        True      41
# 1878          0463-WZZKO    Male          False    False       False       3
# 2933   1664.300049  False
# 2934    198.100006  False
# 2940   2854.550049   True
# 2942    907.049988  False
# 2943    973.950012  False
# 2944    605.750000  False
# 2950     55.700001  False
# 2952    493.950012  False
# 2958     19.549999  False
# 2962     95.050003   True
# 2963    917.150024  False
# 2966    672.700012  False
# 2972   4478.850098  False
# 2976    439.200012  False
# 2977     19.500000  False
# 2980   1866.449951  False
# 2981   1430.949951  False
# 2982   1071.599976  False
# 2984    684.049988  False
# 2987    670.349976  False
# 2988   7880.250000    NaN
# 2989     19.200001  False
# 2990    298.450012   True
# 2992    442.450012  False
# 2993     20.400000  False
# 2994   2345.550049  False
# 2995     25.250000  False
# 2999    414.950012  False

# %%
data["TotalCharges"]=data["TotalCharges"].astype(str)

# %%
# for column in data.select_dtypes(include='object'):
#     data[column + '_encoded'] = pd.factorize(data[column])[0]

# %%
df = pd.concat([data,data2], ignore_index=True)

# %%
df.head()
# Out:
#    customerID  gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female         False    True      False       1        False
# 1  5575-GNVDE    Male         False   False      False      34         True
# 2  3668-QPYBK    Male         False   False      False       2         True
# 3  7795-CFOCW    Male         False   False      False      45        False
# 4  9237-HQITU  Female         False   False      False       2         True
#
#   MultipleLines InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# 0           NaN             DSL          False         True            False
# 1         False             DSL           True        False             True
# 2         False             DSL           True         True            False
# 3           NaN             DSL           True        False             True
# 4         False     Fiber optic          False        False            False
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0       False       False           False  Month-to-month             True
# 1       False       False           False        One year            False
# 2       False       False           False  Month-to-month             True
# 3        True       False           False        One year            False
# 4       False       False           False  Month-to-month             True
#
#                PaymentMethod  MonthlyCharges        TotalCharges  Churn
# 0           Electronic check       29.850000  29.850000381469727  False
# 1               Mailed check       56.950001              1889.5  False
# 2               Mailed check       53.849998   108.1500015258789   True
# 3  Bank transfer (automatic)       42.299999             1840.75  False
# 4           Electronic check       70.699997  151.64999389648438   True

# %%
df[df["Churn"].isnull()]
# Out:
#       customerID gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 2988  6295-OSINB   Male         False    True      False      72         True
#
#      MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 2988          True     Fiber optic           True         True
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies  Contract  \
# 2988             True       False        True            True  Two year
#
#      PaperlessBilling     PaymentMethod  MonthlyCharges TotalCharges Churn
# 2988             True  Electronic check      109.650002      7880.25   NaN

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen        object
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
# import mitosheet
# mitosheet.sheet()

# %% [markdown]
# # Remember random state

# %%
# import mitosheet
# mitosheet.sheet(df, analysis_to_replay="id-ozzvnjyalg")

# %%
# from mitosheet.public.v3 import *; register_analysis("id-ozzvnjyalg");
# import pandas as pd

# # clean the data with standard cleaning techniques
# df.dropna(inplace=True)
# df.drop_duplicates(inplace=True)
# df.reset_index(drop=True, inplace=True)
# df = df.apply(lambda x: x.str.strip() if x.dtype == "object" else x)
# df = df.apply(lambda x: x.str.lower() if x.dtype == "object" else x)

# # number of rows left
# df.shape[0]

# # check distribution of columns with null
# series = df.isnull().sum()
# df2 = pd.DataFrame(series, index=series.index)

# # check distribution for SeniorCitizen
# series = df['SeniorCitizen'].value_counts()
# df3 = pd.DataFrame(series, index=series.index)

# # check rows with nan
# series = df.isnull().sum(axis=1)
# df4 = pd.DataFrame(series, index=series.index)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        5043 non-null   object
#  1   gender            5043 non-null   object
#  2   SeniorCitizen     5043 non-null   object
#  3   Partner           5043 non-null   object
#  4   Dependents        5043 non-null   object
#  5   tenure            5043 non-null   int64
#  6   PhoneService      5043 non-null   object
#  7   MultipleLines     4774 non-null   object
#  8   InternetService   5043 non-null   object
#  9   OnlineSecurity    4392 non-null   object
#  10  OnlineBackup      4392 non-null   object
#  11  DeviceProtection  4392 non-null   object
#  12  TechSupport       4392 non-null   object
#  13  StreamingTV       4392 non-null   object
#  14  StreamingMovies   4392 non-null   object
#  15  Contract          5043 non-null   object
#  16  PaperlessBilling  5043 non-null   object
#  17  PaymentMethod     5043 non-null   object
#  18  MonthlyCharges    5043 non-null   float64
#  19  TotalCharges      5043 non-null   object
#  20  Churn             5042 non-null   object
# dtypes: float64(1), int64(1), object(19)
# memory usage: 827.5+ KB

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
#checking for duplicated files
df.duplicated().any()
# Out:
# False

# %%
df.isnull().any()
# Out:
# customerID          False
# gender              False
# SeniorCitizen       False
# Partner             False
# Dependents          False
# tenure              False
# PhoneService        False
# MultipleLines        True
# InternetService     False
# OnlineSecurity       True
# OnlineBackup         True
# DeviceProtection     True
# TechSupport          True
# StreamingTV          True
# StreamingMovies      True
# Contract            False
# PaperlessBilling    False
# PaymentMethod       False
# MonthlyCharges      False
# TotalCharges        False
# Churn                True
# dtype: bool

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen        object
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
# A quick look at the data
df.head()
# Out:
#    customerID  gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female         False    True      False       1        False
# 1  5575-GNVDE    Male         False   False      False      34         True
# 2  3668-QPYBK    Male         False   False      False       2         True
# 3  7795-CFOCW    Male         False   False      False      45        False
# 4  9237-HQITU  Female         False   False      False       2         True
#
#   MultipleLines InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# 0           NaN             DSL          False         True            False
# 1         False             DSL           True        False             True
# 2         False             DSL           True         True            False
# 3           NaN             DSL           True        False             True
# 4         False     Fiber optic          False        False            False
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0       False       False           False  Month-to-month             True
# 1       False       False           False        One year            False
# 2       False       False           False  Month-to-month             True
# 3        True       False           False        One year            False
# 4       False       False           False  Month-to-month             True
#
#                PaymentMethod  MonthlyCharges        TotalCharges  Churn
# 0           Electronic check       29.850000  29.850000381469727  False
# 1               Mailed check       56.950001              1889.5  False
# 2               Mailed check       53.849998   108.1500015258789   True
# 3  Bank transfer (automatic)       42.299999             1840.75  False
# 4           Electronic check       70.699997  151.64999389648438   True

# %%
# made a copy of the data to perform correlation test on it 
dfc = df.copy()
dfc.dropna(inplace = True)

# %%
dfc["SeniorCitizen"].replace(0, "False", inplace=True)
dfc["SeniorCitizen"].replace(1, "True", inplace=True)
cols = ['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
       'StreamingTV', 'StreamingMovies', 'PaperlessBilling', 'Churn']
dfc[cols] = dfc[cols].replace(" ", "")
#for value in cols:
dfc[cols].replace("No", "False", inplace=True)
dfc[cols].replace("Yes", "True", inplace=True)
dfc[cols] = dfc[cols].astype(bool)
dfc[cols] = dfc[cols].astype(bool)

# %%
dfc["gender"].value_counts()
# Out:
# True    4122
# Name: gender, dtype: int64

# %%
dfc.drop(columns = "TotalCharges", axis=1, inplace = True)

# %%
dfc.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# Churn               0
# dtype: int64

# %%
# import mitosheet
# mitosheet.sheet(dfc, analysis_to_replay="id-oyzxydljqv")
dff = pd.DataFrame()
dff[["tenure", "MonthlyCharges"]] = dfc[["tenure", "MonthlyCharges"]]

# %%
for column in dfc.select_dtypes(include=['object', 'bool']):
    dff[column + '_encoded'] = pd.factorize(dfc[column])[0]

# %%
dff['gender_encoded'].value_counts()
# Out:
# 0    4122
# Name: gender_encoded, dtype: int64

# %%
cor_mat = dff.corr(method='spearman')["Churn_encoded"]
cor_mat
# Out:
# tenure                     -0.209049
# MonthlyCharges             -0.179397
# customerID_encoded          0.621208
# gender_encoded                   NaN
# SeniorCitizen_encoded            NaN
# Partner_encoded             0.321717
# Dependents_encoded          0.465490
# PhoneService_encoded             NaN
# MultipleLines_encoded       0.375465
# InternetService_encoded     0.218164
# OnlineSecurity_encoded     -0.340955
# OnlineBackup_encoded        0.326595
# DeviceProtection_encoded   -0.333731
# TechSupport_encoded         0.326921
# StreamingTV_encoded         0.390753
# StreamingMovies_encoded     0.384527
# Contract_encoded           -0.019424
# PaperlessBilling_encoded    0.391657
# PaymentMethod_encoded      -0.121676
# Churn_encoded               1.000000
# Name: Churn_encoded, dtype: float64

# %%
colms = ['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
       'StreamingTV', 'StreamingMovies', 'PaperlessBilling', 'Churn']
for cols in colms:
    counts = data[cols].value_counts()
    counts1 = data1[cols].value_counts()
    print(f"Value counts for {col}:\n{counts}\n\n{counts1}\n")
# Out:
# Value counts for Column3:
# Male      1054
# Female    1024
# Name: gender, dtype: int64
#  data1 Value counts for Column3:
# Female    1004
# Male       996
# Name: gender, dtype: int64
#
# Value counts for Column3:
# False    1658
# True      420
# Name: SeniorCitizen, dtype: int64
#  data1 Value counts for Column3:
# 0    1677
# 1     323
# Name: SeniorCitizen, dtype: int64
#
# Value counts for Column3:
# False    1059
# True     1019
# Name: Partner, dtype: int64
#  data1 Value counts for Column3:
# No     1056
# Yes     944
# Name: Partner, dtype: int64
#
# Value counts for Column3:
# False    1515
# True      563
# Name: Dependents, dtype: int64
#  data1 Value counts for Column3:
# No     1451
# Yes     549
# Name: Dependents, dtype: int64
#
# Value counts for Column3:
# True    2078
# Name: PhoneService, dtype: int64
#  data1 Value counts for Column3:
# Yes    1807
# No      193
# Name: PhoneService, dtype: int64
#
# Value counts for Column3:
# True     1136
# False     942
# Name: MultipleLines, dtype: int64
#  data1 Value counts for Column3:
# No                  966
# Yes                 841
# No phone service    193
# Name: MultipleLines, dtype: int64
#
# Value counts for Column3:
# False    1325
# True      753
# Name: OnlineSecurity, dtype: int64
#  data1 Value counts for Column3:
# No                     991
# Yes                    563
# No internet service    446
# Name: OnlineSecurity, dtype: int64
#
# Value counts for Column3:
# False    1168
# True      910
# Name: OnlineBackup, dtype: int64
#  data1 Value counts for Column3:
# No                     857
# Yes                    697
# No internet service    446
# Name: OnlineBackup, dtype: int64
#
# Value counts for Column3:
# False    1141
# True      937
# Name: DeviceProtection, dtype: int64
#  data1 Value counts for Column3:
# No                     876
# Yes                    678
# No internet service    446
# Name: DeviceProtection, dtype: int64
#
# Value counts for Column3:
# False    1321
# True      757
# Name: TechSupport, dtype: int64
#  data1 Value counts for Column3:
# No                     1001
# Yes                     553
# No internet service     446
# Name: TechSupport, dtype: int64
#
# Value counts for Column3:
# True     1048
# False    1030
# Name: StreamingTV, dtype: int64
#  data1 Value counts for Column3:
# No                     792
# Yes                    762
# No internet service    446
# Name: StreamingTV, dtype: int64
#
# Value counts for Column3:
# True     1072
# False    1006
# Name: StreamingMovies, dtype: int64
#  data1 Value counts for Column3:
# No                     804
# Yes                    750
# No internet service    446
# Name: StreamingMovies, dtype: int64
#
# Value counts for Column3:
# True     1431
# False     647
# Name: PaperlessBilling, dtype: int64
#  data1 Value counts for Column3:
# Yes    1175
# No      825
# Name: PaperlessBilling, dtype: int64
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Churn'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[181], line 6
#       4 for cols in colms:
#       5     counts = data[cols].value_counts()
# ----> 6     counts1 = data1[cols].value_counts()
#       7     print(f"Value counts for {col}:\n{counts}\n", f"data1 Value counts for {col}:\n{counts1}\n")
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'Churn'

# %%
import pandas as pd

# Sample DataFrame
data = {
    'Column1': ['A', 'B', 'A', 'C', 'B', 'A'],
    'Column2': ['X', 'Y', 'X', 'Z', 'Y', 'Z'],
    'Column3': ['L', 'M', 'M', 'L', 'L', 'M']
}

df = pd.DataFrame(data)
for col in df.columns:
    counts = df[col].value_counts()
    print(f"Value counts for {col}:\n{counts}\n")
# Out:
# Value counts for Column1:
# A    3
# B    2
# C    1
# Name: Column1, dtype: int64
#
# Value counts for Column2:
# X    2
# Y    2
# Z    2
# Name: Column2, dtype: int64
#
# Value counts for Column3:
# L    3
# M    3
# Name: Column3, dtype: int64
